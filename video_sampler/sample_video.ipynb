# %%
import numpy as np 
import cv2
import os
from scipy.io import loadmat

DATA_PATH = r'D:\YL_Wang\Label3d\20240613\M1\videos'
MAT_PATH = r'D:\YL_Wang\Label3d\20240613\M1\20240226_202308_Label3D_dannce.mat'

def video_sample_with_index(video_file_folder, indexes):
    print(indexes)
    print('video_file_folder:', video_file_folder)
    dir_list = os.listdir(video_file_folder)
    print('dir_list:', dir_list)
    for file in dir_list:
        video_file_d = os.path.join(video_file_folder, file)
        video_file = os.listdir(video_file_d)[0]
        video_file = os.path.join(video_file_d, video_file)
        if video_file.endswith('.avi') or video_file.endswith('.mp4'):
            print("run here")
            cap = cv2.VideoCapture(video_file)
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            print('frame_count:', frame_count)
            frames = []
            for index in indexes:
                cap.set(cv2.CAP_PROP_POS_FRAMES, index)
                
                ret = cap.grab()
                if ret:
                    print('grab')
                    ret, frame = cap.retrieve()
                    if ret:
                        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                        frames.append(rgb_frame)

            cap.release()

            frames = np.array(frames)

            # save the frames
            save_folder = os.path.join(video_file_d, 'frames.npy')
            np.save(save_folder, frames)

    return


def get_labeled_frame_index(mat_path):
    mat = loadmat(mat_path)
    label_data = mat['labelData']

    indexes = label_data[0][0][0][0]['data_frame']
    return indexes[0]

# %%
# run here

# indexes = get_labeled_frame_index(MAT_PATH)
# video_sample_with_index(DATA_PATH, indexes)
# Out:
# [    0   225   450   675   900  1125  1350  1575  1800  2025  2250  2475
#   2700  2925  3150  3375  3600  3825  4050  4275  4500  4725  4950  5175
#   5400  5625  5850  6075  6300  6525  6750  6975  7200  7425  7650  7875
#   8100  8325  8550  8775  9000  9225  9450  9675  9900 10125 10350 10575
#  10800 11025 11250 11475 11700 11925 12150 12375 12600 12825 13050 13275
#  13500 13725 13950 14175 14400 14625 14850 15075 15300 15525 15750 15975
#  16200 16425 16650 16875 17100 17325 17550 17775 18000 18225 18450 18675
#  18900 19125 19350 19575 19800 20025 20250 20475 20700 20925 21150 21375
#  21600 21825 22050 22275]
# video_file_folder: D:\YL_Wang\Label3d\20240613\M1\videos
# dir_list: ['Camera1', 'Camera2', 'Camera3', 'Camera4', 'Camera5', 'Camera6']
# run here
# frame_count: 22500
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# run here
# frame_count: 22500
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# run here
# frame_count: 22500
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# run here
# frame_count: 22500
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# run here
# frame_count: 22500
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# run here
# frame_count: 22500
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab
# grab

# %%
# 
mat = loadmat(MAT_PATH)

print(mat.keys())

label_data = mat['labelData']

print(label_data[0][0][0][0]['data_frame'])
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'camnames', 'labelData', 'params', 'sync'])
# [[    0   225   450   675   900  1125  1350  1575  1800  2025  2250  2475
#    2700  2925  3150  3375  3600  3825  4050  4275  4500  4725  4950  5175
#    5400  5625  5850  6075  6300  6525  6750  6975  7200  7425  7650  7875
#    8100  8325  8550  8775  9000  9225  9450  9675  9900 10125 10350 10575
#   10800 11025 11250 11475 11700 11925 12150 12375 12600 12825 13050 13275
#   13500 13725 13950 14175 14400 14625 14850 15075 15300 15525 15750 15975
#   16200 16425 16650 16875 17100 17325 17550 17775 18000 18225 18450 18675
#   18900 19125 19350 19575 19800 20025 20250 20475 20700 20925 21150 21375
#   21600 21825 22050 22275]]

# %%
# have a look
npy_path = r"D:\YL_Wang\Label3d\20240613\M1\videos\Camera6\frames.npy"

import numpy as np

data = np.load(npy_path)

print(data.shape)
# Out:
# (100, 1080, 1440, 3)

# %%
# 
frame_list = list(data)

print(len(frame_list))

print(frame_list[0].shape)
# Out:
# 100
# (1080, 1440, 3)

# %%
indexes = get_labeled_frame_index(MAT_PATH)
shuffled_repeat_indexes = []
for i, index in enumerate(indexes):
    if i < 60:
        shuffled_repeat_indexes.append(index)
    else:
        shuffled_repeat_indexes.append(indexes[60])

np.random.shuffle(shuffled_repeat_indexes)

# %%
print(shuffled_repeat_indexes)
print(len(shuffled_repeat_indexes))
# Out:
# [13500, 9675, 11250, 13500, 8325, 13500, 3150, 13500, 13500, 3825, 10125, 13500, 6750, 13500, 13500, 13500, 7875, 13500, 9450, 13500, 9900, 13500, 13500, 13500, 0, 4500, 13500, 10350, 5175, 2250, 10575, 13500, 13500, 13275, 9000, 13500, 2700, 13500, 900, 7650, 7200, 13500, 13500, 6300, 12150, 2475, 4725, 13500, 12825, 13500, 450, 13500, 13500, 8550, 13500, 13500, 13500, 4950, 3375, 8100, 5400, 6525, 11025, 13500, 13500, 675, 1575, 13500, 9225, 13500, 13500, 8775, 13500, 13500, 7425, 13500, 4275, 13500, 11700, 12600, 1800, 13050, 225, 13500, 2025, 6075, 13500, 2925, 13500, 11925, 5850, 1125, 4050, 6975, 10800, 5625, 12375, 11475, 3600, 1350]
# 100

# %%
# count the most index
from collections import Counter

counter = Counter(shuffled_repeat_indexes)

print(counter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 # count the most index
#       2 from collections import Counter
# ----> 4 counter = Counter(shuffled_repeat_indexes)
#       6 print(counter)
#
# NameError: name 'shuffled_repeat_indexes' is not defined

# %%
def repeat_and_save_the_index(frames_list_path, shuffled_index):
    # repeat the 51 frame 50 times and shuffle
    frames = np.load(frames_list_path)

    repeated_frames = []
    for i, index in enumerate(shuffled_index):
        repeated_frames.append(frames[index])

    return repeated_frames

# %%
## repeat the frames and save and save the shuffled index
# get the index
MAT_PATH = r'D:\YL_Wang\Label3d\20240613\M1\20240226_202308_Label3D_dannce.mat'
indexes = get_labeled_frame_index(MAT_PATH)
index_of_index = np.arange(len(indexes))

shuffled_repeat_indexes = []
for i, index in enumerate(index_of_index):
    if len(shuffled_repeat_indexes) < 100:
        shuffled_repeat_indexes.append(index)
        shuffled_repeat_indexes.append(index)

np.random.shuffle(shuffled_repeat_indexes)
print(shuffled_repeat_indexes)

# get the video index according to the shuffled index
video_index = []
for index in shuffled_repeat_indexes:
    video_index.append(indexes[index])

# folder operations

DATA_PATH = r'D:\YL_Wang\Label3d\20240613\M1\videos'
DATA_INDEX_PATH = r"D:\YL_Wang\Label3d\20240613\M1\video_index"

for file in os.listdir(DATA_PATH):
    if os.path.isfile(os.path.join(DATA_PATH, file)):
        continue
    sub_folder = os.path.join(DATA_PATH, file)
    npy_path = os.path.join(sub_folder, 'frames.npy')
    repeated_frames = repeat_and_save_the_index(npy_path, shuffled_repeat_indexes)
    np.save(os.path.join(sub_folder, 'repeated_frames.npy'), repeated_frames)

np.save(os.path.join(DATA_INDEX_PATH, 'shuffled_repeat_indexes.npy'), shuffled_repeat_indexes)
np.save(os.path.join(DATA_INDEX_PATH, 'video_frames_index.npy'), video_index)
# Out:
# [23, 9, 39, 9, 17, 14, 25, 11, 33, 0, 20, 18, 30, 1, 32, 1, 7, 27, 6, 48, 34, 15, 10, 40, 41, 24, 21, 36, 19, 29, 18, 0, 3, 40, 49, 26, 25, 41, 37, 48, 3, 37, 30, 46, 45, 34, 29, 31, 5, 4, 12, 44, 43, 11, 7, 16, 45, 46, 32, 27, 42, 28, 42, 44, 38, 2, 22, 49, 21, 13, 17, 8, 5, 39, 6, 33, 36, 16, 8, 4, 47, 43, 31, 15, 23, 47, 2, 13, 20, 22, 28, 26, 38, 24, 12, 35, 10, 35, 14, 19]

# %%
# load video data
import numpy as np

l = np.load(r"D:\YL_Wang\Label3d\20240613\M1\videos\Camera1\repeated_frames.npy")

print(l.shape)
# Out:
# (100, 1080, 1440, 3)
